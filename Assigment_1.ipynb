# %% [markdown]
# Q-1. Who discovered Python programming language?
# Ans- Guido Van Rossum
#
# Q-2. Which type of Programming does Python support?
# Ans- Python supports Object Oriented, Structured and functional programming.
#
# Q-3. Is Python case sensitive when dealing with identifiers?
# Ans- Yes, Python is case sensitive when dealing with identifiers.
#
# Q-4. What is the correct extension of the python file?
# Ans- The correct extension of the Python file is .py for source file and .pyc for compiled file
#
# Q-5. Is python compiled or interpreted?
# Ans- Python is an Interpreted language.
#
# Q-6. Name a few blocks of code used to define in Python language?
# Ans- Module, Function body and Class definition.
#
# Q-7. State a character used to give single-line comments in Python language?
# Ans- #
#
# Q-8. Mention functions which can help us to find the version of python what we are currently working on?
# Ans- sys.version
#
# Q-9. Python supports the creation of anonymous functions at runtime, using a construct called......
# Ans- lambda
#
# Q-10. What does pip stand for python?
# Ans-  Pip Install Packages
#
# Q-11. Mention a few built-in functions in python?
# Ans-  print(), input(), int(), float(), next(), open(), zip(), type(), tuple()
#
# Q-12. What is the maximum possible length of an identifier in Python?
# Ans-  79 characters
#
# Q-13. What are the benefits of using Python?
# Ans- Following are the benefits of using Python:-
#      i. It is Simple to use and understand
#     ii. Python is Free and Open source
#    iii. Python is portable language.
#    iv.  Python has extensive library.
#      v. Python has supportive community.
#
# Q-14. How is memory managed in Python?
# Ans-  Memory is managed in Python through a private heap containing all Python objects and data structures.
#       The management of this private heap is ensured internally by the Python memory manager
#
# Q-15. How to install Python on windows and set path variables ?
# Ans-  Dowload the python by searching python download on web browser.
#       Following are the steps to install Python on windows after download and set path variables:
#       Step-1. Right click on My Computer and click on properties.
#       Step-2. Click on Advanced System settings
#       Step-3. Click on Environment Variable tab
#       Step-4. Click on new tab of user variables.
#       Step-5. Write path in variable name
#       Step-6. Copy the path of Python folder
#       Step-7. Paste path of Python in variable value.
#       Step-8. Click on OK button.
#
# Q-16. Is indentation required in Python?
# Ans-  Yes, indentation is required in Python.
